# %%
from sklearn.datasets import load_iris
import pandas as pd
import os
import numpy as np

# %%
df=pd.read_csv('titanic_data.csv')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
name_get=df["name"]
#OR
name_get=df.name

# %%
type(name_get)
# Out:
# pandas.core.series.Series

# %%
# SELECT Columns

col=['name','survived','sex','sibsp']
df=df[col]

# %%
##  to select row(s) and column(s)
## 
## iloc -> integer locate
## loc -> locate

## syntax -> df.iloc[row(int),column(int)]
## syntax -> df.loc[row(index),column(name)]

# %%
df.head()
# Out:
#                                               name  survived     sex  sibsp
# 0                    Allen, Miss. Elisabeth Walton         1  female      0
# 1                   Allison, Master. Hudson Trevor         1    male      1
# 2                     Allison, Miss. Helen Loraine         0  female      1
# 3             Allison, Mr. Hudson Joshua Creighton         0    male      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         0  female      1

# %%
#df.iloc[1,0]
#or
#df.iloc[:,0] # it will take full columns

# %%
df.loc[1308,'name'] # it take row as integer and column as string
df.loc[:,['name','sex']]
# Out:
#                                                  name     sex
# 0                       Allen, Miss. Elisabeth Walton  female
# 1                      Allison, Master. Hudson Trevor    male
# 2                        Allison, Miss. Helen Loraine  female
# 3                Allison, Mr. Hudson Joshua Creighton    male
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...                                               ...     ...
# 1304                             Zabour, Miss. Hileni  female
# 1305                            Zabour, Miss. Thamine  female
# 1306                        Zakarian, Mr. Mapriededer    male
# 1307                              Zakarian, Mr. Ortin    male
# 1308                               Zimmerman, Mr. Leo    male
#
# [1309 rows x 2 columns]

# %% [markdown]
# # Filter

# %%
df.head()
# Out:
#                                               name  survived     sex  sibsp
# 0                    Allen, Miss. Elisabeth Walton         1  female      0
# 1                   Allison, Master. Hudson Trevor         1    male      1
# 2                     Allison, Miss. Helen Loraine         0  female      1
# 3             Allison, Mr. Hudson Joshua Creighton         0    male      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         0  female      1

# %%
# find only females
f=df["sex"]=="female"

# %%
df[f]
# Out:
#                                                  name  survived     sex  sibsp
# 0                       Allen, Miss. Elisabeth Walton         1  female      0
# 2                        Allison, Miss. Helen Loraine         0  female      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         0  female      1
# 6                   Andrews, Miss. Kornelia Theodosia         1  female      1
# 8       Appleton, Mrs. Edward Dale (Charlotte Lamson)         1  female      2
# ...                                               ...       ...     ...    ...
# 1286  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)         1  female      0
# 1290                 Wilkes, Mrs. James (Ellen Needs)         1  female      1
# 1300          Yasbeck, Mrs. Antoni (Selini Alexander)         1  female      1
# 1304                             Zabour, Miss. Hileni         0  female      1
# 1305                            Zabour, Miss. Thamine         0  female      1
#
# [466 rows x 4 columns]

# %%
new_df=df.loc[f,["pclass","name","sex","ticket","cabin"]]

# %%
#Check if it contains some required thing then filter

# %%
new_df.head()
# Out:
#    pclass                                             name     sex  ticket  \
# 0       1                    Allen, Miss. Elisabeth Walton  female   24160
# 2       1                     Allison, Miss. Helen Loraine  female  113781
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  113781
# 6       1                Andrews, Miss. Kornelia Theodosia  female   13502
# 8       1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female   11769
#
#      cabin
# 0       B5
# 2  C22 C26
# 4  C22 C26
# 6       D7
# 8     C101

# %%
# filter data for cabin C22

# %%
filter_=new_df["cabin"].str.contains("C")

# %%
new_df
# Out:
#       pclass                                             name     sex  ticket  \
# 0          1                    Allen, Miss. Elisabeth Walton  female   24160
# 2          1                     Allison, Miss. Helen Loraine  female  113781
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  113781
# 6          1                Andrews, Miss. Kornelia Theodosia  female   13502
# 8          1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female   11769
# ...      ...                                              ...     ...     ...
# 1286       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female    2688
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female  363272
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female    2659
# 1304       3                             Zabour, Miss. Hileni  female    2665
# 1305       3                            Zabour, Miss. Thamine  female    2665
#
#         cabin
# 0          B5
# ...

# %%
new_df[filter_]
# Out:
#      pclass                                               name     sex  \
# 2         1                       Allison, Miss. Helen Loraine  female
# 4         1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 8         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 11        1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# 24        1                                  Bird, Miss. Ellen  female
# 28        1                             Bissette, Miss. Amelia  female
# 32        1                            Bonnell, Miss. Caroline  female
# 33        1                           Bonnell, Miss. Elizabeth  female
# 42        1     Brown, Mrs. John Murray (Caroline Lane Lamson)  female
# 61        1  Cavendish, Mrs. Tyrell William (Julia Florence...  female
# 72        1      Clark, Mrs. Walter Miller (Virginia McDowell)  female
# 79        1  Cornell, Mrs. Robert Clifford (Malvina Helen L...  female
# ...

# %% [markdown]
# ### filter With two or more conditions

# %%
# filter if female and c in cabin

# %%
df.head()
# Out:
#                                               name  survived     sex  sibsp
# 0                    Allen, Miss. Elisabeth Walton         1  female      0
# 1                   Allison, Master. Hudson Trevor         1    male      1
# 2                     Allison, Miss. Helen Loraine         0  female      1
# 3             Allison, Mr. Hudson Joshua Creighton         0    male      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)         0  female      1

# %%
# mutiple conditions apply here 
 # and or etc
f=((df['sex']=="female") & (df["cabin"].str.contains("C")) & ((df['embarked']=="S") | (df['embarked']=="C"))) & (df["boat"]!="?")

# %%
new_=df[f]

# %%
new_.head()

# %%
#isin()

# to check given data is in list or not
list_=[0,1]

f=(new_["sibsp"].isin(list_)) & ((new_['sex']=="female") &( (new_['sibsp']<=1) &  (new_['age']!="?")))

# %%
new_[f]
# Out:
#      pclass  survived                                               name  \
# 11        1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 24        1         1                                  Bird, Miss. Ellen
# 28        1         1                             Bissette, Miss. Amelia
# 32        1         1                            Bonnell, Miss. Caroline
# 33        1         1                           Bonnell, Miss. Elizabeth
# 61        1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 72        1         1      Clark, Mrs. Walter Miller (Virginia McDowell)
# 85        1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 98        1         1        Douglas, Mrs. Walter Donald (Mahala Dutton)
# 102       1         1              Earnshaw, Mrs. Boulton (Olive Potter)
# 103       1         1                      Endres, Miss. Caroline Louise
# 116       1         1                Fortune, Mrs. Mark (Mary McDougald)
# ...

# %% [markdown]
# ### INDEXING

# %%
df=pd.read_csv('titanic_data.csv')
df.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
df.reset_index(inplace=True)

# %%
df.index=df['name']

# %%
df_n = df.set_index('survived')
df_n.head()
# Out:
#           index  pclass                                             name  \
# survived
# 1             0       1                    Allen, Miss. Elisabeth Walton
# 1             1       1                   Allison, Master. Hudson Trevor
# 0             2       1                     Allison, Miss. Helen Loraine
# 0             3       1             Allison, Mr. Hudson Joshua Creighton
# 0             4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#              sex     age  sibsp  parch  ticket      fare    cabin embarked  \
# survived
# 1         female      29      0      0   24160  211.3375       B5        S
# 1           male  0.9167      1      2  113781    151.55  C22 C26        S
# 0         female       2      1      2  113781    151.55  C22 C26        S
# 0           male      30      1      2  113781    151.55  C22 C26        S
# 0         female      25      1      2  113781    151.55  C22 C26        S
#
#          boat body                        home.dest
# ...

# %% [markdown]
# ## Play with columns

# %%
# rename columns

# %%
df.rename(columns={"name":"Names", "age":"All ages"}, inplace=True)

# %%
df
# Out:
#                                                  index  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0       1         1
# Allison, Master. Hudson Trevor                       1       1         1
# Allison, Miss. Helen Loraine                         2       1         0
# Allison, Mr. Hudson Joshua Creighton                 3       1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4       1         0
# ...                                                ...     ...       ...
# Zabour, Miss. Hileni                              1304       3         0
# Zabour, Miss. Thamine                             1305       3         0
# Zakarian, Mr. Mapriededer                         1306       3         0
# Zakarian, Mr. Ortin                               1307       3         0
# Zimmerman, Mr. Leo                                1308       3         0
#
# ...

# %%
#Drop clumns
df.drop(columns=["Names","All ages"], inplace=True)

# %%
df
# Out:
#                                                  index  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0       1         1
# Allison, Master. Hudson Trevor                       1       1         1
# Allison, Miss. Helen Loraine                         2       1         0
# Allison, Mr. Hudson Joshua Creighton                 3       1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4       1         0
# ...                                                ...     ...       ...
# Zabour, Miss. Hileni                              1304       3         0
# Zabour, Miss. Thamine                             1305       3         0
# Zakarian, Mr. Mapriededer                         1306       3         0
# Zakarian, Mr. Ortin                               1307       3         0
# Zimmerman, Mr. Leo                                1308       3         0
#
#                                                     sex  sibsp  parch  ticket  \
# ...

# %%
# adding new columns
df['other'] = df['sex'] + ' ' + df['fare']

# %%
df
# Out:
#                                                  index  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0       1         1
# Allison, Master. Hudson Trevor                       1       1         1
# Allison, Miss. Helen Loraine                         2       1         0
# Allison, Mr. Hudson Joshua Creighton                 3       1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4       1         0
# ...                                                ...     ...       ...
# Zabour, Miss. Hileni                              1304       3         0
# Zabour, Miss. Thamine                             1305       3         0
# Zakarian, Mr. Mapriededer                         1306       3         0
# Zakarian, Mr. Ortin                               1307       3         0
# Zimmerman, Mr. Leo                                1308       3         0
#
#                                                     sex  sibsp  parch  ticket  \
# ...

# %% [markdown]
# ## CHANGING DATA IN DATAFRAME

# %%
df.head()
# Out:
#                                                  index  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0       1         1
# Allison, Master. Hudson Trevor                       1       1         1
# Allison, Miss. Helen Loraine                         2       1         0
# Allison, Mr. Hudson Joshua Creighton                 3       1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4       1         0
#
#                                                     sex  sibsp  parch  ticket  \
# name
# Allen, Miss. Elisabeth Walton                    female      0      0   24160
# Allison, Master. Hudson Trevor                     male      1      2  113781
# Allison, Miss. Helen Loraine                     female      1      2  113781
# Allison, Mr. Hudson Joshua Creighton               male      1      2  113781
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      1      2  113781
#
# ...

# %%
df.loc["Allison, Miss. Helen Loraine",'pclass']=66

# %%
df.head()
# Out:
#                                                  index  pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0       1         1
# Allison, Master. Hudson Trevor                       1       1         1
# Allison, Miss. Helen Loraine                         2      66         0
# Allison, Mr. Hudson Joshua Creighton                 3       1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4       1         0
#
#                                                     sex  sibsp  parch  ticket  \
# name
# Allen, Miss. Elisabeth Walton                    female      0      0   24160
# Allison, Master. Hudson Trevor                     male      1      2  113781
# Allison, Miss. Helen Loraine                     female      1      2  113781
# Allison, Mr. Hudson Joshua Creighton               male      1      2  113781
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      1      2  113781
#
# ...

# %%
df.replace({66:"HEYY", "female":"FEMALEEE"})
# Out:
#                                                 index pclass survived  \
# name
# Allen, Miss. Elisabeth Walton                       0      1        1
# Allison, Master. Hudson Trevor                      1      1        1
# Allison, Miss. Helen Loraine                        2   HEYY        0
# Allison, Mr. Hudson Joshua Creighton                3      1        0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     4      1        0
# ...                                               ...    ...      ...
# Zabour, Miss. Hileni                             1304      3        0
# Zabour, Miss. Thamine                            1305      3        0
# Zakarian, Mr. Mapriededer                        1306      3        0
# Zakarian, Mr. Ortin                              1307      3        0
# Zimmerman, Mr. Leo                               1308      3        0
#
#                                                       sex sibsp parch  ticket  \
# name
# ...

# %%
df["pclass"]=df["pclass"].replace({66:36666663})

# %%
df
# Out:
#                                                  index    pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0         1         1
# Allison, Master. Hudson Trevor                       1         1         1
# Allison, Miss. Helen Loraine                         2  36666663         0
# Allison, Mr. Hudson Joshua Creighton                 3         1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4         1         0
# ...                                                ...       ...       ...
# Zabour, Miss. Hileni                              1304         3         0
# Zabour, Miss. Thamine                             1305         3         0
# Zakarian, Mr. Mapriededer                         1306         3         0
# Zakarian, Mr. Ortin                               1307         3         0
# Zimmerman, Mr. Leo                                1308         3         0
#
# ...

# %%
# change some items of row

df.loc["Zimmerman, Mr. Leo",["pclass","survived"]]=[44,44]

# %%
df
# Out:
#                                                  index    pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0         1         1
# Allison, Master. Hudson Trevor                       1         1         1
# Allison, Miss. Helen Loraine                         2  36666663         0
# Allison, Mr. Hudson Joshua Creighton                 3         1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4         1         0
# ...                                                ...       ...       ...
# Zabour, Miss. Hileni                              1304         3         0
# Zabour, Miss. Thamine                             1305         3         0
# Zakarian, Mr. Mapriededer                         1306         3         0
# Zakarian, Mr. Ortin                               1307         3         0
# Zimmerman, Mr. Leo                                1308        44        44
#
# ...

# %%
# def foo(name):
#     return name.upper()

# df['name'].apply(foo)

# %%
df["Names"]=df.index

# %%
df.head()
# Out:
#                                                  index    pclass  survived  \
# name
# Allen, Miss. Elisabeth Walton                        0         1         1
# Allison, Master. Hudson Trevor                       1         1         1
# Allison, Miss. Helen Loraine                         2  36666663         0
# Allison, Mr. Hudson Joshua Creighton                 3         1         0
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)      4         1         0
#
#                                                     sex  sibsp  parch  ticket  \
# name
# Allen, Miss. Elisabeth Walton                    female      0      0   24160
# Allison, Master. Hudson Trevor                     male      1      2  113781
# Allison, Miss. Helen Loraine                     female      1      2  113781
# Allison, Mr. Hudson Joshua Creighton               male      1      2  113781
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      1      2  113781
#
# ...

# %%
def change_name(names):
    if "?" in names:
        names=names.replace("?","--")
        return names
    else:
        return "Nopty"

# %%
df['Pbody'] = df['body'].apply(change_name)

# %%
# df["pname"]="Nopty"

# %%
df[df["Pbody"]=="Nopty"]
# Out:
#                                       index  pclass  survived     sex  sibsp  \
# name
# Allison, Mr. Hudson Joshua Creighton      3       1         0    male      1
# Artagaveytia, Mr. Ramon                   9       1         0    male      0
# Astor, Col. John Jacob                   10       1         0    male      1
# Birnbaum, Mr. Jakob                      25       1         0    male      0
# Brandeis, Mr. Emil                       39       1         0    male      0
# ...                                     ...     ...       ...     ...    ...
# Williams, Mr. Leslie                   1294       3         0    male      0
# Wirz, Mr. Albert                       1296       3         0    male      0
# Youseff, Mr. Gerious                   1301       3         0    male      0
# Zabour, Miss. Hileni                   1304       3         0  female      1
# Zakarian, Mr. Mapriededer              1306       3         0    male      0
#
# ...

# %% [markdown]
# # Sorting DataFrame

# %%
 df=pd.read_csv('titanic_data.csv')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df.sort_values(by=["fare","age","ticket","survived"], ascending=[False,True,False,True])
# Out:
#       pclass  survived                                               name  \
# 1225       3         0                                 Storey, Mr. Thomas
# 225        1         0                         Payne, Mr. Vivian Ponsonby
# 230        1         1                              Perreault, Miss. Anne
# 155        1         1  Hays, Mrs. Charles Melville (Clara Jennings Gr...
# 154        1         0                         Hays, Mr. Charles Melville
# ...      ...       ...                                                ...
# 384        2         0                     Cunningham, Mr. Alfred Fleming
# 528        2         0                        Parkes, Mr. Francis 'Frank'
# 125        1         0                                   Fry, Mr. Richard
# 223        1         0                      Parr, Mr. William Henry Marsh
# 70         1         0              Chisholm, Mr. Roderick Robert Crispin
#
#          sex   age  sibsp  parch  ticket  fare cabin embarked boat body  \
# ...

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
import pandas as pd

# %% [markdown]
# # Mathematical Calculation

# %%
dict_={"name":["ashish","rahul","mohan","amit","ashish","mohan"],"maths":[45,2,1,4,5,3],"science":[4,8,9,5,7,3.7]}
dfs=pd.DataFrame(dict_)
dfs
# Out:
#      name  maths  science
# 0  ashish     45      4.0
# 1   rahul      2      8.0
# 2   mohan      1      9.0
# 3    amit      4      5.0
# 4  ashish      5      7.0
# 5   mohan      3      3.7

# %%
dfs["science"].sum()
# Out:
# 36

# %%
list(df.sum(axis=1))

# %%
df.mean()
df.sum()
df.median()
# Out:
# pclass      3.0
# survived    0.0
# sibsp       0.0
# parch       0.0
# dtype: float64

# %%
df["pclass"].max()
# Out:
# 3

# %%
df.max()
# Out:
# pclass                                 3
# survived                               1
# name         van Melkebeke, Mr. Philemon
# sex                                 male
# age                                    ?
# sibsp                                  8
# parch                                  9
# ticket                         WE/P 5735
# fare                                   ?
# cabin                                  T
# embarked                               S
# boat                                   D
# body                                   ?
# home.dest            Zurich, Switzerland
# dtype: object

# %%
df["survived"].describe()
# Out:
# count    1309.000000
# mean        0.381971
# std         0.486055
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: survived, dtype: float64

# %% [markdown]
# # Grouping Data

# %%
dfs
# Out:
#      name  maths  science
# 0  ashish     45      4.0
# 1   rahul      2      8.0
# 2   mohan      1      9.0
# 3    amit      4      5.0
# 4  ashish      5      7.0
# 5   mohan      3      3.7

# %%
gp=dfs.groupby(by="science")
gp

# %%
for x,oo in gp:
    display(x,oo)
# Out:
# 3.7
#     name  maths  science
# 5  mohan      3      3.7
# 4.0
#      name  maths  science
# 0  ashish     45      4.0
# 5.0
#    name  maths  science
# 3  amit      4      5.0
# 7.0
#      name  maths  science
# 4  ashish      5      7.0
# 8.0
#     name  maths  science
# 1  rahul      2      8.0
# 9.0
#     name  maths  science
# 2  mohan      1      9.0

# %%
dfs["maths"].value_counts() # Cont all values in group -- for every group
# Out:
# 1     1
# 2     1
# 3     1
# 4     1
# 45    1
# 5     1
# Name: maths, dtype: int64

# %%
gp.mean()
# Out:
#         maths  science
# name
# amit        4     5.00
# ashish     25     5.50
# mohan       2     6.35
# rahul       2     8.00

# %%
dfs
# Out:
#      name  maths  science
# 0  ashish     45      4.0
# 1   rahul      2      8.0
# 2   mohan      1      9.0
# 3    amit      4      5.0
# 4  ashish      5      7.0
# 5   mohan      3      3.7

# %%
gp.get_group("ashish") # to get data of one group from all group
# Out:
#      name  maths  science
# 0  ashish     45      4.0
# 4  ashish      5      7.0

# %% [markdown]
# # Convert DataType in Dataframe

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1       1.0                    Allen, Miss. Elisabeth Walton  female
# 1       1       1.0                   Allison, Master. Hudson Trevor    male
# 2       1       0.0                     Allison, Miss. Helen Loraine  female
# 3       1       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df['survived']=df['survived'].apply(lambda x: float(x))

# %%
df['survived'].dtypes
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1       1.0                    Allen, Miss. Elisabeth Walton  female
# 1       1       1.0                   Allison, Master. Hudson Trevor    male
# 2       1       0.0                     Allison, Miss. Helen Loraine  female
# 3       1       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df['sibsp']=df['sibsp'].astype(int)  # changing directly

# %%
df=df.astype({"sibsp":str})

df['sibsp'].astype
# Out:
# <bound method NDFrame.astype of 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: object>

# %%
df['sex'].apply(lambda x : x.title())
# Out:
# 0       Female
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 1304    Female
# 1305    Female
# 1306      Male
# 1307      Male
# 1308      Male
# Name: sex, Length: 1309, dtype: object

# %%
df=pd.read_csv('titanic_data.csv')

def change(ty):
    if ty=="?":
        return 0
    else:
        return float(ty)
df['age']=df['age'].apply(change)

# %%
df["age"].astype
df["survived"].astype
# Out:
# <bound method NDFrame.astype of 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64>

# %%
#convert type 
df["salary"]= ["$"+str(x) for x in df["survived"]+df["age"]]

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    ?
# 1   0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2   2.0000      1      2  113781    151.55  C22 C26        S    ?    ?
# 3  30.0000      1      2  113781    151.55  C22 C26        S    ?  135
# 4  25.0000      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest   salary
# ...

# %%
df['salary']=df.salary.str.replace("$",'')
# Out:
# <ipython-input-933-9e539f0e39ae>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df['salary']=df.salary.str.replace("$",'')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    ?
# 1   0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2   2.0000      1      2  113781    151.55  C22 C26        S    ?    ?
# 3  30.0000      1      2  113781    151.55  C22 C26        S    ?  135
# 4  25.0000      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest  salary
# ...

# %% [markdown]
# # Handling missing values

# %%
dict_={"name":["ashish","rahul","mohan","amit","ashish","mohan"],"maths":[45,None,1,4,None,3],"science":[4,None,9,5,None,3.7]}
dfs=pd.DataFrame(dict_)
dfs
# Out:
#      name  maths  science
# 0  ashish   45.0      4.0
# 1   rahul    NaN      NaN
# 2   mohan    1.0      9.0
# 3    amit    4.0      5.0
# 4  ashish    NaN      NaN
# 5   mohan    3.0      3.7

# %%
dfs.fillna(338888)
# Out:
#      name     maths   science
# 0  ashish      45.0       4.0
# 1   rahul  338888.0  338888.0
# 2   mohan       1.0       9.0
# 3    amit       4.0       5.0
# 4  ashish  338888.0  338888.0
# 5   mohan       3.0       3.7

# %%
dict_={"name":["ashish","rahul","mohan","amit","ashish","mohan"],"maths":[45,None,1,4,None,3],"science":[4,None,9,5,None,3.7]}

dfs=pd.DataFrame(dict_)
dfs
# Out:
#      name  maths  science
# 0  ashish   45.0      4.0
# 1   rahul    NaN      NaN
# 2   mohan    1.0      9.0
# 3    amit    4.0      5.0
# 4  ashish    NaN      NaN
# 5   mohan    3.0      3.7

# %%
dfs.fillna({"maths":3454545})
# Out:
#      name      maths  science
# 0  ashish       45.0      4.0
# 1   rahul  3454545.0      NaN
# 2   mohan        1.0      9.0
# 3    amit        4.0      5.0
# 4  ashish  3454545.0      NaN
# 5   mohan        3.0      3.7

# %%
# Filling methods

# %% [markdown]
# \ ffill , bfill

# %%
dict_={"name":["ashish","rahul","mohan","amit","ashish","mohan"],"maths":[45,None,1,4,None,3],"science":[4,None,9,5,None,3.7]}
dfs=pd.DataFrame(dict_)
dfs
# Out:
#      name  maths  science
# 0  ashish   45.0      4.0
# 1   rahul    NaN      NaN
# 2   mohan    1.0      9.0
# 3    amit    4.0      5.0
# 4  ashish    NaN      NaN
# 5   mohan    3.0      3.7

# %%
dfs['maths'].fillna(method='ffill')
# Out:
# 0    45.0
# 1    45.0
# 2     1.0
# 3     4.0
# 4     4.0
# 5     3.0
# Name: maths, dtype: float64

# %%
dfs.dropna()
# Out:
#      name  maths  science
# 0  ashish   45.0      4.0
# 2   mohan    1.0      9.0
# 3    amit    4.0      5.0
# 5   mohan    3.0      3.7

# %%
dfs.dropna(how="all")
# Out:
#      name  maths  science
# 0  ashish   45.0      4.0
# 1   rahul    NaN      NaN
# 2   mohan    1.0      9.0
# 3    amit    4.0      5.0
# 4  ashish    NaN      NaN
# 5   mohan    3.0      3.7

# %%
dfs.dropna(how="any")
# Out:
#      name  maths  science
# 0  ashish   45.0      4.0
# 2   mohan    1.0      9.0
# 3    amit    4.0      5.0
# 5   mohan    3.0      3.7

# %% [markdown]
# # Concat

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'ID': [1,2,3,4],
                  'Name': ['A', 'B', 'C','D'],
                  'Class': [5,6,7,8]})

# %%
df2 = pd.DataFrame({'ID': [5,6,7],
                  'Name': ['E', 'G', 'H'],
                  'Class': [9,10,11],
                  'Rollcll': [9,10,11]})

df3 = pd.DataFrame({'ID': [5,6,7, 10],
                  'Name': ['E', 'G', 'H', "C"],
                  'Class': [9,10,11, 34]})

# %%
pd.concat([df1,df2,df3], axis=0, ignore_index=True) # ignore_index to Serialize index
# Out:
#     ID Name  Class  Rollcll
# 0    1    A      5      NaN
# 1    2    B      6      NaN
# 2    3    C      7      NaN
# 3    4    D      8      NaN
# 4    5    E      9      9.0
# 5    6    G     10     10.0
# 6    7    H     11     11.0
# 7    5    E      9      NaN
# 8    6    G     10      NaN
# 9    7    H     11      NaN
# 10  10    C     34      NaN

# %%
sr1 = pd.Series([0,1,2])

sr2 = pd.Series([3,4,5,6,7])

# %%
vv=pd.concat([sr1,sr2])

# %%
(vv)
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
df1 = pd.DataFrame({'ID': [1,2,3,4],
                  'Name': ['A', 'B', 'C','D'],
                  'Class': [5,6,7,8]})
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2 = pd.DataFrame({'ID': [3,4],
                  'Name': ['C','D'],
                  'Class': [7,8]})
df2
# Out:
#    ID Name  Class
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      5  3.0    C    7.0
# 1   2    B      6  4.0    D    8.0
# 2   3    C      7  NaN  NaN    NaN
# 3   4    D      8  NaN  NaN    NaN

# %%
pd.concat([df1, df2], axis = 1, join = 'inner')
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      5   3    C      7
# 1   2    B      6   4    D      8

# %%
pd.concat([df1, df2], axis = 1, join = 'outer')
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      5  3.0    C    7.0
# 1   2    B      6  4.0    D    8.0
# 2   3    C      7  NaN  NaN    NaN
# 3   4    D      8  NaN  NaN    NaN

# %%
#

# %%
pd.concat([df1, df2], keys = ['First df','Second df'])
# Out:
#              ID Name  Class
# First df  0   1    A      5
#           1   2    B      6
#           2   3    C      7
#           3   4    D      8
# Second df 0   3    C      7
#           1   4    D      8

# %%
pd.concat([df1, df2], sort = True)
# Out:
#    Class  ID Name
# 0      5   1    A
# 1      6   2    B
# 2      7   3    C
# 3      8   4    D
# 0      7   3    C
# 1      8   4    D

# %%
pd.concat([df1, df2], sort = False)
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   3    C      7
# 1   4    D      8

# %% [markdown]
# # Join Function

# %%
df1 = pd.DataFrame({'A': [1,2,3],
                   'B': [10,20,30]})
 
df2 = pd.DataFrame({'C': [4,5,6],
                   'D': [40,50,60]})
 
display(df1, df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    C   D
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1 = pd.DataFrame({'A': [1,2,3],
                   'B': [10,20,30]},
                   index = ['a','b','c'])
 
df2 = pd.DataFrame({'C': [4,5],
                   'D': [40,50]},
                  index = ['a','b'])
 
display(df1, df2)
# Out:
#    A   B
# a  1  10
# b  2  20
# c  3  30
#    C   D
# a  4  40
# b  5  50

# %%
df1.join(df2)
# Out:
#    A   B    C     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
# IF index is same ----
df1 = pd.DataFrame({'A': [1,2,3],
                   'B': [10,20,30]},
                   index = ['a','b','c'])
 
df2 = pd.DataFrame({'B': [4,5],
                   'D': [40,50]},
                  index = ['a','b'])
df1.join(df2,  lsuffix = '_1')
# Out:
#    A  B_1    B     D
# a  1   10  4.0  40.0
# b  2   20  5.0  50.0
# c  3   30  NaN   NaN

# %%
# IF index is same ----
df1 = pd.DataFrame({'A': [1,2,3],
                   'B': [10,20,30]},
                   index = ['a','b','c'])
 
df2 = pd.DataFrame({'C': [4,5],
                   'D': [40,50]},
                  index = ['a','b'])

# %%
df1.join(df2,how="inner")
# Out:
#    A   B  C   D
# a  1  10  4  40
# b  2  20  5  50

# %%
df1.join(df2,how="outer")
# Out:
#    A   B    C     D
# a  1  10  4.0  40.0
# b  2  20  5.0  50.0
# c  3  30  NaN   NaN

# %%
#@ only inner and outer join can be used in This

# %%
# Append function Pandas -- same like concat

# %% [markdown]
# ## Append

# %%
df1 = pd.DataFrame({'A': [1,2,3],
                   'B': [10,20,30]})
 
 
df2 = pd.DataFrame({'A': [4,5,6],
                   'B': [40,50,60]})
 
display(df1 ,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    A   B
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1.append(df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1.append(df2, ignore_index = True)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50
# 5  6  60

# %%
df1 = pd.DataFrame({'A': [1,2,3],
                   'B': [10,20,30]})
 
 
df2 = pd.DataFrame({'C': [4,5,6],
                   'B': [40,50,60]})
 
display(df1 ,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
#    C   B
# 0  4  40
# 1  5  50
# 2  6  60

# %%
df1.append(df2, ignore_index = True, sort = False)
# Out:
#      A   B    C
# 0  1.0  10  NaN
# 1  2.0  20  NaN
# 2  3.0  30  NaN
# 3  NaN  40  4.0
# 4  NaN  50  5.0
# 5  NaN  60  6.0
